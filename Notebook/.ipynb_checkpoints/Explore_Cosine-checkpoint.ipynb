# %% [markdown]
# ##### import

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import torch

sys.path.append("../Lib")

from mcmc import MetropolisGauss
from square import Square
from flow import BG_RealNVP
from plot import plot_forward_backward_2d
from explore import Configuration

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
energy_array=np.load('..\Data\square_data\energy_two_squares.npy')

# %%
density=np.exp(-energy_array)

n_sample=10000

Ix, Iy = np.meshgrid(np.arange(density.shape[0]), np.arange(density.shape[1]))
idx = np.vstack([Ix.flatten(), Iy.flatten()]).T
density_normed = density.astype(np.float64)
density_normed /= density_normed.sum()
density_flat = density_normed.flatten()
i = np.random.choice(idx.shape[0], size=n_sample, p=density_flat)
ixy = idx[i, :]
mean = np.array([90,90])
scale = np.array([2,2])
xy = ixy  - 0.5 +  0* np.random.rand(n_sample, 2)
xy = xy  / scale-mean

ax=plt.gca()
ax.hist2d(xy[:,0],xy[:,1],bins=100,norm=matplotlib.colors.LogNorm())
plt.show()

# %%
x_brute=xy.astype('float32')

# %%
x0 = x_brute[100:101]
X0 = np.repeat(x0, 1000, axis=0)
X0 += 0.01 * np.random.randn(X0.shape[0], X0.shape[1])

# %%
ax=plt.gca()
ax.hist2d(x_brute[:,0],x_brute[:,1],bins=100,norm=matplotlib.colors.LogNorm())

plt.plot(x0[:, 0], x0[:, 1], color='red', linewidth=0, marker='+', markersize=20, markeredgewidth=3)

plt.show()

# %% [markdown]
# ### Explore

# %%
model=Square(n_square = 2, energy_array = energy_array)

# %%
model_SNF=BG_RealNVP(model,dim=model.dim,stochastic=True,step_size=0.05, nsteps=5, n_hidden=256, n_block=8)

# %%
Explore_square=Configuration(model_SNF,X0.astype('float32'),capacity=10000)

# %%
ax=plt.gca()
ax.hist2d(Explore_DoubleWell.X[:,0],Explore_DoubleWell.X[:,1],bins=100,norm=matplotlib.colors.LogNorm())
plt.show()
plot_energy(Explore_DoubleWell.X[:,0]) #plot energy
# Out:
# 0

# %%
Explore_square.stepsize
# Out:
# []

# %%
Explore_square.configure(epochs=10,iter=20,lr=1e-4)
# Out:
# iter 0: loss = 4995118592.000
# iter 1: loss = 4990237184.000
# iter 2: loss = 5014650368.000
# iter 3: loss = 4995118592.000
# iter 4: loss = 5009766400.000
# iter 5: loss = 4995120128.000
# iter 6: loss = 5000001536.000
# iter 7: loss = 4985354240.000
# iter 8: loss = 5009767424.000
# iter 9: loss = 4995118592.000

# %%
x=model_SNF.sample(10000)[1]

# %%
ax=plt.gca()
ax.hist2d(x[:,0],x[:,1],bins=100,norm=matplotlib.colors.LogNorm())
plt.show()

# %%
plt.plot(Explore_DoubleWell.acceptance_rate)

# %%
ax=plt.gca()
ax.hist2d(Explore_DoubleWell.X[:,0],Explore_DoubleWell.X[:,1],bins=100,norm=matplotlib.colors.LogNorm())
plt.show()
plot_energy(Explore_DoubleWell.X[:,0]) #plot energy

# %%
plt.plot(Explore_DoubleWell.stepsize)
