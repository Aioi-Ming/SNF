# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import torch
import time

sys.path.append("../Lib")

from mcmc import MetropolisGauss
from cosine import Cosine
from flow import BG_RealNVP
from plot import plot_forward_backward_2d

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
model=Cosine(w=3)

# %%
_=model.plot_dimer_energy()

# %%
nsteps = 500000
stride = 10
noise=0.05
burnin=100000
xl=np.array([-0.5,0])
xr=np.array([0.5,0])

# %%
sampler_l = MetropolisGauss(model, xl, noise=noise, burnin=burnin, stride=stride)
sampler_l.run(nsteps)

# %%
sampler_r = MetropolisGauss(model, xr, noise=noise, burnin=burnin, stride=stride)
sampler_r.run(nsteps)

# %%
xl=sampler_l.traj
xr=sampler_r.traj

# %%
x_brute=np.vstack((xl,xr))
x_brute.shape
# Out:
# (80000, 2)

# %%
_=model.plot_sample_energy(x_brute)

# %%
model_BG=BG_RealNVP(model,dim=model.dim)

# %%
loss=model_BG.train_ML(x_brute,iter=1500,lr=1e-4,batch_size=2048)
plt.plot(loss)

# %%
plot_forward_backward_2d(model_BG,x_brute,10000)

# %%
z, x, _ = model_BG.sample(10000)
_=model.plot_sample_energy(x)

# %%
model_BG=BG_RealNVP(model,dim=model.dim)

# %%
loss=model_BG.train_mix(x_brute,iter=1500,lr=1e-4,batch_size=2048)
plt.plot(loss)

# %%
plot_forward_backward_2d(model_BG,x_brute,10000)

# %%
z, x, _ = model_BG.sample(10000)
_=model.plot_sample_energy(x)

# %%
model_BG=BG_RealNVP(model,dim=model.dim)

# %%
loss=model_BG.train_KL(iter=2000,training_data_size=10000,lr=1e-6,batch_size=2048)
plt.plot(loss)

# %%
plot_forward_backward_2d(model_BG,x_brute,10000)

# %%
z, x, _ = model_BG.sample(10000)
_=model.plot_sample_energy(x)
